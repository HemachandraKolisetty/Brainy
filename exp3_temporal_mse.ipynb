# %%
from dataloader import load_data_one_hot_encoded
from trainer import train_model, evaluate_model
from snn import SNNModelSimple
import torch
import matplotlib.pyplot as plt
import pickle

# %%
root_folder = "./tactile_dataset/"
file_name = "final_merged_df_sw500.csv"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

train_losses_l = {}
train_accuracies_l = {}
val_losses_l = {}
val_accuracies_l = {}
test_accuracies_l = {}

for lr in [1e-4, 1e-3, 5e-3, 1e-2, 5e-2]:
    print(f"Training for lr={lr}")
    train_loader, val_loader, test_loader, num_outputs, num_features = load_data_one_hot_encoded(root_folder, file_name, spike_encoding='temporal', num_steps=50, batch_size=128, device=device)

    model = SNNModelSimple(num_features, num_outputs)
    model.to(device)
    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    train_losses, train_accuracies, val_losses, val_accuracies = train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs=10)
    train_losses_l[lr] = train_losses
    train_accuracies_l[lr] = train_accuracies
    val_losses_l[lr] = val_losses
    val_accuracies_l[lr] = val_accuracies

    test_accuracies_l[lr] = evaluate_model(model, test_loader,encoding='one-hot')

out_file_name = 'exp3_temporal_lr_1e-4_5e-2_t_50_bs_128_ep_10_temporal_mse.pkl'
with open(out_file_name, 'wb') as f:
    pickle.dump({"train_losses": train_losses_l, "train_accuracies": train_accuracies_l, "val_losses": val_losses_l, "val_accuracies": val_accuracies_l, "test_accuracies": test_accuracies_l}, f)
# Out:
# cpu
# Training for lr=0.0001
# Epoch 1/10, Train Loss: 0.0785, Train Accuracy: 8.80%, Val Loss: 17.3109, Val Accuracy: 9.40%, Time: 25.96s
# Epoch 2/10, Train Loss: 0.0763, Train Accuracy: 9.52%, Val Loss: 17.0955, Val Accuracy: 11.39%, Time: 23.63s
# Epoch 3/10, Train Loss: 0.0762, Train Accuracy: 11.35%, Val Loss: 17.3539, Val Accuracy: 11.83%, Time: 23.89s
# Epoch 4/10, Train Loss: 0.0757, Train Accuracy: 13.63%, Val Loss: 17.3904, Val Accuracy: 16.47%, Time: 25.40s
# Epoch 5/10, Train Loss: 0.0749, Train Accuracy: 20.53%, Val Loss: 18.8343, Val Accuracy: 23.70%, Time: 27.88s
# Epoch 6/10, Train Loss: 0.0739, Train Accuracy: 24.01%, Val Loss: 21.4265, Val Accuracy: 25.04%, Time: 25.47s
# Epoch 7/10, Train Loss: 0.0731, Train Accuracy: 25.34%, Val Loss: 22.0656, Val Accuracy: 26.06%, Time: 23.41s
# Epoch 8/10, Train Loss: 0.0724, Train Accuracy: 26.12%, Val Loss: 24.7815, Val Accuracy: 27.12%, Time: 23.36s
# Epoch 9/10, Train Loss: 0.0719, Train Accuracy: 26.09%, Val Loss: 25.2452, Val Accuracy: 26.22%, Time: 23.47s
# Epoch 10/10, Train Loss: 0.0712, Train Accuracy: 27.14%, Val Loss: 25.9170, Val Accuracy: 28.30%, Time: 24.42s
# Best model loaded with Validation Accuracy: 28.30%
# Test Accuracy: 29.07%, Time: 3.47s
# Training for lr=0.001
# Epoch 1/10, Train Loss: 0.0757, Train Accuracy: 13.16%, Val Loss: 23.3637, Val Accuracy: 21.91%, Time: 23.61s
# Epoch 2/10, Train Loss: 0.0696, Train Accuracy: 28.58%, Val Loss: 31.4275, Val Accuracy: 32.54%, Time: 23.84s
# Epoch 3/10, Train Loss: 0.0662, Train Accuracy: 35.71%, Val Loss: 33.1141, Val Accuracy: 34.98%, Time: 25.27s
# Epoch 7/10, Train Loss: 0.0478, Train Accuracy: 60.27%, Val Loss: 62.9938, Val Accuracy: 60.03%, Time: 24.68s
# Epoch 8/10, Train Loss: 0.0471, Train Accuracy: 61.03%, Val Loss: 61.1796, Val Accuracy: 61.02%, Time: 23.56s
# Epoch 9/10, Train Loss: 0.0466, Train Accuracy: 61.90%, Val Loss: 62.3210, Val Accuracy: 61.39%, Time: 23.79s
# Epoch 10/10, Train Loss: 0.0462, Train Accuracy: 62.56%, Val Loss: 55.4731, Val Accuracy: 63.05%, Time: 22.95s
# Best model loaded with Validation Accuracy: 63.05%
# Test Accuracy: 63.02%, Time: 3.78s
# Training for lr=0.05
# Epoch 1/10, Train Loss: 0.0684, Train Accuracy: 25.95%, Val Loss: 50.8277, Val Accuracy: 37.46%, Time: 22.86s
# Epoch 2/10, Train Loss: 0.0592, Train Accuracy: 42.44%, Val Loss: 44.7121, Val Accuracy: 45.79%, Time: 22.67s
# Epoch 3/10, Train Loss: 0.0568, Train Accuracy: 47.09%, Val Loss: 50.3678, Val Accuracy: 47.09%, Time: 23.46s
# Epoch 4/10, Train Loss: 0.0554, Train Accuracy: 49.63%, Val Loss: 49.0619, Val Accuracy: 50.79%, Time: 22.78s
# Epoch 5/10, Train Loss: 0.0544, Train Accuracy: 50.51%, Val Loss: 54.0675, Val Accuracy: 50.28%, Time: 22.91s
# Epoch 6/10, Train Loss: 0.0533, Train Accuracy: 52.71%, Val Loss: 52.1905, Val Accuracy: 52.71%, Time: 22.94s
# Epoch 7/10, Train Loss: 0.0524, Train Accuracy: 54.10%, Val Loss: 53.5674, Val Accuracy: 54.82%, Time: 22.60s
# Epoch 8/10, Train Loss: 0.0519, Train Accuracy: 54.87%, Val Loss: 56.4026, Val Accuracy: 53.59%, Time: 22.94s
# Epoch 9/10, Train Loss: 0.0515, Train Accuracy: 55.13%, Val Loss: 55.1422, Val Accuracy: 55.79%, Time: 22.94s
# Epoch 10/10, Train Loss: 0.0514, Train Accuracy: 55.16%, Val Loss: 52.1271, Val Accuracy: 54.00%, Time: 24.20s
# Best model loaded with Validation Accuracy: 55.79%
# Test Accuracy: 54.03%, Time: 3.28s

# %%
# Plotting
plt.figure()
for lr in train_losses_l.keys():
    plt.plot(train_losses_l[lr], label=f"lr={lr}")
    plt.xlabel("Epoch")
    plt.ylabel("Train Loss")
    plt.legend()
    plt.title("Train Loss vs Epoch")

plt.figure()
for lr in train_accuracies_l.keys():
    plt.plot(train_accuracies_l[lr], label=f"lr={lr}")
    plt.xlabel("Epoch")
    plt.ylabel("Train Accuracy")
    plt.legend()
    plt.title("Train Accuracy vs Epoch")

plt.figure()
for lr in val_losses_l.keys():
    plt.plot(val_losses_l[lr], label=f"lr={lr}")
    plt.xlabel("Epoch")
    plt.ylabel("Validation Loss")
    plt.legend()
    plt.title("Validation Loss vs Epoch")

plt.figure()
for lr in val_accuracies_l.keys():
    plt.plot(val_accuracies_l[lr], label=f"lr={lr}")
    plt.xlabel("Epoch")
    plt.ylabel("Validation Accuracy")
    plt.legend()
    plt.title("Validation Accuracy vs Epoch")

plt.figure()
plt.bar([str(x) for x in test_accuracies_l.keys()], test_accuracies_l.values())
plt.xlabel("Learning Rate")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Learning Rate")
plt.show()
